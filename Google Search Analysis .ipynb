# %% [markdown]
# # importing the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing pytrends

# %%
pip install pytrends
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16109 sha256=a5e579afad8f88c1fbab22d0d0dfd244eb2f0a274dbe202fa5a22db0f96e2e9b
#   Stored in directory: c:\users\shahn\appdata\local\pip\cache\wheels\e8\78\c8\18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\shahn\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# for installing pytrends "pip install pytrends"
from pytrends.request import TrendReq
trends=TrendReq()

# %% [markdown]
# # Pre Processing Steps

# %%
trends.build_payload(kw_list=["Machine Learning"])
data=trends.interest_by_region()
data=data.sort_values(by="Machine Learning",ascending=False)
data=data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Singapore                  44
# St. Helena                 30
# India                      30
# Hong Kong                  23
# Pakistan                   21
# South Korea                21
# Nepal                      17
# Bangladesh                 17
# Tunisia                    16

# %% [markdown]
# # Visualize the Bar Chart

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", figsize=(15,5), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# # Seeing last 3-4 years trend for the keyword

# %%
data=TrendReq(hl='en-US',tz=360)
data.build_payload(kw_list=["Machine Learning"])
data=data.interest_over_time()
fig, ax= plt.subplots(figsize=(20,15))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Google searches for Machine Learning past 4 years', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
